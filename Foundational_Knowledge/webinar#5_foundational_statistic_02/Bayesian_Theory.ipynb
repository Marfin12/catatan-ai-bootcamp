# %%
from IPython.display import Image, display

display(Image(filename="bayes_formula.png"))
display(Image(filename="example_case.png"))

# %% [markdown]
# ## References
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html
#
# https://app.excalidraw.com/l/sVN0wZtutU/5WeiJnvgThr
#
# https://docs.google.com/document/d/1uBsZzPL1Bhy_i4r9JT3_QswsjPQwunOJCuYzbigzEec/edit?tab=t.0
